# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## A bit of info before you start.
#
#
# > ***First and foremost, dont use AI to code. Use it to understand and then write code yourself. Use AI to verify if the code you wrote it correct, that will help you learn far far more.***
#
# > ***Implement Stuff from sratch. Use cv2 functions only when numpy implementation can be extremely tedious.***
#
#
#
# You will need to use your own image for this assignment, which you need to import into here.
# If you cant fetch your image from any APIs that dont need credentials, then :
# To preserve an image in Google Colab without a continuous runtime or using Google Drive, you can use base64 string encoding of images ( its really simple )
#
# First, begin by normally uploading the image into the contents folders as you normally do in colab or fetch it using Drive or any API.
#
# To get the base64 string :
# ```
# import base64
# with open("your_image.jpg", "rb") as img_file:
#     print(base64.b64encode(img_file.read()).decode())
# ```
#
# Note that the base64 string is a very long string, click on the three dot icon to the left of the current code cell and click on <code> Copy Cell Output </code> to easily copy it to your clipboard.
#
# Then, to embed the string into your Jupyter Notebook :
# ```
# from PIL import Image
# import io
# import base64
# import matplotlib.pyplot as plt
# import numpy as np
#
# # PASTE BASE64 STRING HERE
# base64_image = "iVBORw0K..."  # long base64 string
#
# img_data = base64.b64decode(base64_image)
# img = Image.open(io.BytesIO(img_data))
#
# plt.imshow(img)
# plt.axis("off")
# ```
# The string is really long so, use a multiline string in python ( syntax : """ """ )
#
# Otherwise, you can also choose to use any API ( try researching on https://picsum.photos/ )

# %% [markdown]
# ## Part A
#
# ### Load your image
#
# 1. Display it in RGB
#
# 2. Convert to grayscale ( use NumPy to calculate aggregates using the weighted sum formula )
#
# 3. Use the cvtColor function to do the same and compare results
#
# 3. Print the array shapes of both the RGB and grayscale images
#
# 4. Print a few pixel values of both
#
# ( Do you notice the difference that number of channels created on the array shape ?? )

# %%
# Your PART A codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import io
import base64
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
filename = list(uploaded.keys())[0]
print("Uploaded:", filename)
# Out:
#      <input type="file" id="files-425ded81-8d6b-4d70-a445-60deba67c371" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-425ded81-8d6b-4d70-a445-60deba67c371">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import base64
with open( filename, "rb") as img_file:
    print(base64.b64encode(img_file.read()).decode())
# Out:
# ...

# %%
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

base64_image = """..."""


img_data = base64.b64decode(base64_image)
img = Image.open(io.BytesIO(img_data))

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(258.5), np.float64(193.5), np.float64(-0.5))

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'download (1).jpeg',
#  'download.jpeg',
#  'download(1).jpeg',
#  'download(2).jpeg',
#  'sample_data']

# %%
import cv2
img_bgr=cv2.imread("download.jpeg")
img_rgb=cv2.cvtColor(img_bgr , cv2.COLOR_BGR2RGB)
plt.figure(figsize=(6,6))
plt.imshow(img_rgb)
plt.title("Original Image(RGB)")
plt.axis("off")
plt.show()

# %%
#convertingto grayscale using numpy
R=img_rgb[:,:,0]
G=img_rgb[:,:,1]
B=img_rgb[:,:,2]

wt_frm =(0.299*R + 0.587*G + 0.114*B ).astype(np.uint8)
plt.figure(figsize=(6,6))
plt.imshow(wt_frm ,cmap='gray')
plt.title("grayscale_numpy")
plt.axis("off")
plt.show()

# %%
#converting to grayscale using cv2
gray =cv2.cvtColor( img_rgb , cv2.COLOR_RGB2GRAY)
plt.figure(figsize=(6,6))
plt.imshow(gray ,cmap='gray')
plt.title("grayscale_cv2")
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.imshow(wt_frm, cmap='gray')
plt.title("Grayscale_numpy")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale_cv2")
plt.axis("off")
plt.show()

# %%
print("RGB_Shape:", img_rgb.shape)
print("Grayscale_numpy_Shape:", wt_frm.shape)
print("Grayscale_cv2_shape:", gray.shape)
# Out:
# RGB_Shape: (194, 259, 3)
# Grayscale_numpy_Shape: (194, 259)
# Grayscale_cv2_shape: (194, 259)

# %%
coordinates = [(10 ,20) ,(100 ,130),(140,150)]
for(x,y) in coordinates:
    print("grayscale_numpy:",wt_frm[x,y],", grayscale_cv2:",gray[x,y],"\n")
# Out:
# grayscale_numpy: 169 , grayscale_cv2: 170
#
# grayscale_numpy: 13 , grayscale_cv2: 14
#
# grayscale_numpy: 145 , grayscale_cv2: 146

# %% [markdown]
# ## Part B
# ### B1. Compute the FFT of the grayscale image ( use NumPy )
# Steps:
# 1. <code>np.fft.fft2</code>
# 2. <code>np.fft.fftshift</code>
# 3. Store as <code>fshift</code>
#
# ### B2. Compute magnitude, phase and display Magnitude Spectrum

# %%
# Your PART B codes follow here. You can create more cells under this. Write clean and commented code.

# %%
gray_float=gray.astype(np.float32)
#fft
f= np.fft.fft2(gray_float)
f_shift=np.fft.fftshift(f)

# %%
magnitude=20*np.log(np.abs(f_shift)+1)
phase =np.angle(f_shift)

plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.imshow(wt_frm, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(magnitude, cmap='gray')
plt.title('Magnitude spec')
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(phase, cmap='twilight')
plt.title('Phase')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Part C
# ### C1. Create 3 LPF masks
#
# Radii of filter: 10, 30, 80 (or image-size dependent, mention if you change)
#
# For each:
#
# 1. Create a mask
#
# 2. Apply to <code>fshift</code>
#
# 3. Reconstruct using <code>ifftshift + ifft2</code>
#
# 4. Show blur levels increasing as radius decreases ( think why and write reason in code comment )
#
# ### C2. Create HPF mask
#
# 1. Apply
#
# 2. Reconstruct
#
# ### C3. Create a square LPF mask
# Keep side of square as 50. The square will be at the center of the filter.
# Apply, Recontruct and show the output.

# %%
# Your PART C codes follow here. You can create more cells under this. Write clean and commented code.

# %%
#Low pass mask
rows, cols = gray.shape
crow,ccol = rows//2 , cols//2

radius =10
mask_lpf = np.zeros((rows , cols ), np.uint8)
cv2.circle(mask_lpf, (ccol,crow),radius , 1 ,-1)
f_lpf=f_shift*mask_lpf
ishift_lpf=np.fft.ifftshift(f_lpf)
img_back_lpf=np.fft.ifft2(ishift_lpf)
img_back_lpf=np.abs(img_back_lpf)
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.axis("off")
plt.title("original")

plt.subplot(1,2,2)
plt.imshow(img_back_lpf, cmap='gray')
plt.axis("off")
plt.title("radius=10")
# Out:
# Text(0.5, 1.0, 'radius=10')

# %%
radius =30
mask_lpf = np.zeros((rows , cols ), np.uint8)
cv2.circle(mask_lpf, (ccol,crow),radius , 1 ,-1)
f_lpf=f_shift*mask_lpf
ishift_lpf=np.fft.ifftshift(f_lpf)
img_back_lpf=np.fft.ifft2(ishift_lpf)
img_back_lpf=np.abs(img_back_lpf)
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
plt.imshow(img_back_lpf, cmap='gray')
plt.axis("off")
plt.title("radius=30")



radius =80
mask_lpf = np.zeros((rows , cols ), np.uint8)
cv2.circle(mask_lpf, (ccol,crow),radius , 1 ,-1)
f_lpf=f_shift*mask_lpf
ishift_lpf=np.fft.ifftshift(f_lpf)
img_back_lpf=np.fft.ifft2(ishift_lpf)
img_back_lpf=np.abs(img_back_lpf)

plt.subplot(1,2,2)
plt.imshow(img_back_lpf, cmap='gray')
plt.axis("off")
plt.title("radius=80")
#Blur increases as the radius decreases because low frequencies are located at the center of the FFT.
#smaller radius contain mostly low frequencies and low frequencies make  more blurred image
# Out:
# Text(0.5, 1.0, 'radius=80')

# %%
#High frequency mask
rows, cols = gray.shape
crow,ccol = rows//2 , cols//2

radius =100
mask_lpf = np.zeros((rows , cols ), np.uint8)
cv2.circle(mask_lpf, (ccol,crow),radius , 1 ,-1)
mask_hpf = 1 - mask_lpf
f_hpf=f_shift*mask_hpf
ishift_hpf=np.fft.ifftshift(f_hpf)
img_back_hpf=np.fft.ifft2(ishift_hpf)
img_back_hpf=np.abs(img_back_hpf)
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.imshow(img_back_hpf, cmap='gray')
plt.axis("off")
plt.title("hpf r=100")

radius =30
mask_lpf = np.zeros((rows , cols ), np.uint8)
cv2.circle(mask_lpf, (ccol,crow),radius , 1 ,-1)
mask_hpf = 1 - mask_lpf
f_hpf=f_shift*mask_hpf
ishift_hpf=np.fft.ifftshift(f_hpf)
img_back_hpf=np.fft.ifft2(ishift_hpf)
img_back_hpf=np.abs(img_back_hpf)

plt.subplot(1,2,2)
plt.imshow(img_back_hpf, cmap='gray')
plt.axis("off")
plt.title("hpf r=30")
# Out:
# Text(0.5, 1.0, 'hpf r=30')

# %%
#LPF square
rows, cols = gray.shape
crow,ccol = rows//2 , cols//2
side=50
mask_lpf_sq=np.zeros((rows,cols),np.uint8)
cv2.rectangle(mask_lpf_sq, (ccol,crow),(side ,side), 1 ,-1)
f_lpf_sq=f_shift*mask_lpf_sq
ishift_sq= np.fft.ifftshift(f_lpf_sq)
img_back = np.fft.ifft2(ishift_sq)
img_sq = np.abs(img_back)
plt.figure(figsize=(15,6))
plt.imshow(img_sq , cmap='gray')
plt.axis("off")
plt.title("LPF Square")
plt.show()

# %% [markdown]
# ## Part D
#
# ###D1. Phase-only reconstruction
#
# Use: <code>phase_only = fshift / np.abs(fshift)</code>
#
# 1. Reconstruct and display.
# 2. Also in code comments, mention the differnce between this code line and the one in the lecture : <code>np.angle(f_shift)</code>
# 3. Try recontruction from <code>np.angle(f_shift)</code> once and explain your output in code comments.
#
#
#
# ###D2. Magnitude-only reconstruction
#
# Use: <code>mag_only = np.abs(fshift)</code>
#
# 1. Reconstruct and display.
# 2. Take a guess for the role of logarithm in Magnitude Spectrum. Why does this look different than what Magnitude Spectrum looked like ? Mention in code comments again.

# %%
# Your PART D codes follow here. You can create more cells under this. Write clean and commented code.

# %%
gray_float=gray.astype(np.float32)
#fft
f= np.fft.fft2(gray_float)
f_shift=np.fft.fftshift(f)
phase_only = f_shift/np.abs(f_shift)

ishift_re=np.fft.ifftshift(phase_only)
img_back_re=np.fft.ifft2(ishift_re)
img_back_re=np.abs(img_back_re)

plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.imshow(img_back_re, cmap='twilight')
plt.title('Phase only')
plt.axis("off")
plt.show()

phase =np.angle(f_shift)
plt.subplot(1,2,2)
plt.imshow(phase, cmap='twilight')
plt.title('Phase')
plt.axis("off")
plt.show()

# %%
#Magnitude only reconstruction
magnitude_only=np.abs(f_shift)
ishift_mag_re=np.fft.ifftshift(magnitude_only)
img_back_mag_re=np.fft.ifft2(ishift_re)
img_back_mag_re=np.abs(img_back_re)

plt.figure(figsize=(15,6))
plt.imshow(img_back_mag_re,cmap='gray')
plt.title("magnitude only reconstruction")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Bonus - Part E
#
# Load another image as you did before. Then swap magnitude and phase between them. In other words, for both images, find the magnitudes and phases. Combine magnitude of image 1 with phase of image 2. Also combine magnitude of 2 with phase of 1. Then reconstruct and display the resultant images.
#
# ![image.png](data:image/png;base64,...)
#
# Do you notice how phase describes structure and magnitude describes texture of image ? Mention at last in code comments.

# %%
# Your PART E codes follow here. You can create more cells under this. Write clean and commented code.

# %%
from google.colab import files
uploaded = files.upload()
filename = list(uploaded.keys())[0]
print("Uploaded:", filename)
# Out:
#      <input type="file" id="files-04ca86ba-f971-4e58-9228-38a61e6c4cfc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04ca86ba-f971-4e58-9228-38a61e6c4cfc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
filename = list(uploaded.keys())[0]
print("Uploaded:", filename)
# Out:
#      <input type="file" id="files-8758c9b7-ba9e-4a11-878b-0fba70da1453" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8758c9b7-ba9e-4a11-878b-0fba70da1453">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img1 = cv2.imread("download(1).jpeg")
img2 = cv2.imread("download(2).jpeg")

# %%
img1 = cv2.resize(img1, (256,256))
img2 = cv2.resize(img2, (256,256))

# %%
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img1)
plt.axis("off")
plt.show()

# %%
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.axis("off")
plt.show()

# %%
# Getting fshift for image 1
img1_gray = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)
f1 = np.fft.fft2(img1_gray)
fshift1 = np.fft.fftshift(f1)

# %%
# Getting fshift for image 2
img2_gray = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)
f2 = np.fft.fft2(img2_gray)
fshift2 = np.fft.fftshift(f2)

# %%
fshift1_mag = np.abs(fshift1) # Magnitude only for FFT of image 1
fshift1_phase = fshift1 / fshift1_mag # Phase only for FFT of image 1

fshift2_mag = np.abs(fshift2) # Magnitude only for FFT of image 2
fshift2_phase = fshift2 / fshift2_mag # Phase only for FFT of image 2

# %%
# Exchanging phases of image using the same magnitude
fshift1_new = fshift1_mag * fshift2_phase
fshift2_new = fshift2_mag * fshift1_phase

# %%
fshift1_new_shift = np.fft.ifftshift(fshift1_new)
fshift2_new_shift = np.fft.ifftshift(fshift2_new)

# %%
img1_new = np.fft.ifft2(fshift1_new_shift)
img2_new = np.fft.ifft2(fshift2_new_shift)

# %%
# Getting the reconstructed image. Using absolute helps in resolving the complex values of pixels
img1_new = np.abs(img1_new)
img2_new = np.abs(img2_new)

# %%
plt.imshow(img1_new)
plt.axis("off")
plt.show()

# %%
plt.imshow(img2_new)
plt.axis("off")
plt.show()

# %%
plt.subplot(2,2,1)
plt.imshow(img1_gray, cmap='gray')
plt.title("First Image")
plt.axis("off")

plt.subplot(2,2,2)
plt.imshow(img1_new, cmap='gray')
plt.title("Reconstructed Image")
plt.axis("off")

plt.subplot(2,2,3)
plt.imshow(img2_gray, cmap='gray')
plt.title("Second Image")
plt.axis("off")

plt.subplot(2,2,4)
plt.imshow(img2_new, cmap='gray')
plt.title("Reconstructed Image")
plt.axis("off")

plt.suptitle("Visualising phase and magnitude...", fontsize = 16)
plt.show()
